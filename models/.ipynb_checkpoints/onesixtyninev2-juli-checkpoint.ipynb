# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.api import VAR
from scipy.stats import norm
from sklearn.metrics import r2_score

# %%
# Laste poll-of-polls data
df = pd.read_csv("../data/v2_data_juli.csv", sep=",")

# %%
df
# Out:
#            Mnd    Ap  Hoyre   Frp   SV   SP  KrF  Venstre  MDG  Rodt  ...  \
# 0    1/31/2008  29.3   17.2  23.9  7.4  6.1  6.4      6.5  0.0   1.3  ...
# 1    2/29/2008  29.0   17.3  25.2  6.7  5.9  6.3      6.6  0.0   1.3  ...
# 2    3/31/2008  28.7   18.1  25.2  7.0  5.6  6.1      6.3  0.0   1.1  ...
# 3    4/30/2008  29.0   16.9  25.4  6.5  5.5  7.0      6.8  0.0   1.2  ...
# 4    5/31/2008  28.9   17.8  25.9  6.7  5.7  6.2      6.2  0.0   1.4  ...
# ..         ...   ...    ...   ...  ...  ...  ...      ...  ...   ...  ...
# 208  5/31/2025  28.5   18.7  20.6  7.0  5.7  3.6      4.1  2.7   5.3  ...
# 209  6/30/2025  28.3   16.2  21.0  6.9  5.6  3.7      4.5  3.0   6.2  ...
# 210  7/31/2025  27.5   14.8  21.5  8.2  6.3  3.2      4.7  3.5   5.9  ...
# 211  8/31/2025   NaN    NaN   NaN  NaN  NaN  NaN      NaN  NaN   NaN  ...
# 212  9/30/2025   NaN    NaN   NaN  NaN  NaN  NaN      NaN  NaN   NaN  ...
#
#      Rodt_reg_lag3  Rodt_reg_lag6  Andre_reg_lag3  Andre_reg_lag6  ledighet  \
# 0              NaN            NaN             NaN             NaN       2.6
# 1              NaN            NaN             NaN             NaN       2.6
# 2              0.0            NaN             0.0             NaN       2.6
# 3              0.0            NaN             0.0             NaN       2.7
# 4              0.0            NaN             0.0             NaN       2.8
# ..             ...            ...             ...             ...       ...
# 208            0.0            0.0             0.0             0.0       4.0
# 209            0.0            0.0             0.0             0.0       4.0
# 210            0.0            0.0             0.0             0.0       4.0
# 211            0.0            0.0             0.0             0.0       4.0
# 212            0.0            0.0             0.0             0.0       4.0
#
#      ledig_trend3  ledig_trend6  styringsrente  styringsrente_trend3  \
# 0             NaN           NaN           5.25                   NaN
# 1             NaN           NaN           5.25                   NaN
# 2           0.000           NaN           5.25              0.000000
# 3           0.033           NaN           5.31              0.020000
# 4           0.067           NaN           5.50              0.083333
# ..            ...           ...            ...                   ...
# 208         0.000     -0.016667           4.20             -0.100000
# 209         0.000     -0.016667           4.20              0.000000
# 210         0.000     -0.016667           4.00             -0.066667
# 211         0.000      0.000000           4.00             -0.066667
# 212         0.000      0.000000           4.00              0.000000
#
#      styringsrente_trend6
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 208             -0.050000
# 209             -0.050000
# 210             -0.083333
# 211             -0.083333
# 212             -0.033333
#
# [213 rows x 77 columns]

# %%
ex_future=df[df['Ap'].isna()][['Mnd',
       'Ap_skandale_lag6', 'Hoyre_skandale_lag6', 'Frp_skandale_lag6',
       'SV_skandale_lag6', 'SP_skandale_lag6', 'KrF_skandale_lag6',
        'Rodt_skandale_lag6',
        'Ap_reg_lag6',
        'Hoyre_reg_lag6', 
        #'Frp_reg_lag6','SV_reg_lag6', 
        #'SP_reg_lag6','KrF_reg_lag6',
        #'Venstre_reg_lag6', 
       'ledighet', 'ledig_trend3', 'ledig_trend6', 'styringsrente',
       'styringsrente_trend3', 'styringsrente_trend6']]

# %%
ex_future
ex_future["Mnd"] = pd.to_datetime(df["Mnd"])
ex_future.set_index("Mnd", inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             Mnd    Ap  Hoyre   Frp   SV   SP  KrF  Venstre  MDG  Rodt  ...  \
# 5     6/30/2008  26.0   17.6  28.9  6.9  5.3  6.1      5.9  0.0   1.8  ...
# 6     7/31/2008  26.9   17.2  30.2  6.6  4.7  6.1      5.4  0.0   1.9  ...
# 7     8/31/2008  26.6   16.2  30.9  6.7  5.2  5.5      6.0  0.0   1.7  ...
# 8     9/30/2008  28.9   15.2  29.9  6.3  5.0  5.7      5.9  0.0   1.5  ...
# 9    10/31/2008  30.6   16.1  26.7  7.3  5.3  5.6      5.5  0.0   1.2  ...
# ..          ...   ...    ...   ...  ...  ...  ...      ...  ...   ...  ...
# 206   3/31/2025  28.1   18.8  22.7  7.2  4.9  3.1      4.3  2.7   4.6  ...
# 207   4/30/2025  28.1   19.8  20.0  6.3  6.7  3.3      3.9  3.1   4.8  ...
# 208   5/31/2025  28.5   18.7  20.6  7.0  5.7  3.6      4.1  2.7   5.3  ...
# 209   6/30/2025  28.3   16.2  21.0  6.9  5.6  3.7      4.5  3.0   6.2  ...
# 210   7/31/2025  27.5   14.8  21.5  8.2  6.3  3.2      4.7  3.5   5.9  ...
#
#      Rodt_reg_lag3  Rodt_reg_lag6  Andre_reg_lag3  Andre_reg_lag6  ledighet  \
# 5              0.0            0.0             0.0             0.0       2.9
# 6              0.0            0.0             0.0             0.0       2.9
# 7              0.0            0.0             0.0             0.0       3.0
# 8              0.0            0.0             0.0             0.0       3.1
# 9              0.0            0.0             0.0             0.0       3.1
# ..             ...            ...             ...             ...       ...
# 206            0.0            0.0             0.0             0.0       4.0
# 207            0.0            0.0             0.0             0.0       4.0
# 208            0.0            0.0             0.0             0.0       4.0
# 209            0.0            0.0             0.0             0.0       4.0
# 210            0.0            0.0             0.0             0.0       4.0
#
#      ledig_trend3  ledig_trend6  styringsrente  styringsrente_trend3  \
# 5           0.067      0.050000           5.54              0.076667
# 6           0.033      0.050000           5.75              0.083333
# 7           0.033      0.066667           5.75              0.070000
# 8           0.067      0.066667           5.75              0.000000
# 9           0.033      0.050000           5.45             -0.100000
# ..            ...           ...            ...                   ...
# 206        -0.033      0.000000           4.50              0.000000
# 207        -0.033     -0.016667           4.20             -0.100000
# 208         0.000     -0.016667           4.20             -0.100000
# 209         0.000     -0.016667           4.20              0.000000
# 210         0.000     -0.016667           4.00             -0.066667
#
#      styringsrente_trend6
# 5                0.048333
# 6                0.083333
# 7                0.083333
# 8                0.073333
# 9               -0.008333
# ..                    ...
# 206              0.000000
# 207             -0.050000
# 208             -0.050000
# 209             -0.050000
# 210             -0.083333
#
# [206 rows x 77 columns]

# %%
# Convert to datetime and set the date to the end of the month
df["Mnd"] = pd.to_datetime(df["Mnd"])

# %%
# Sort values and set index
df = df.sort_values("Mnd")
df.set_index("Mnd", inplace=True)

# %%
df
# Out:
#               Ap  Hoyre   Frp   SV   SP  KrF  Venstre  MDG  Rodt  Andre  ...  \
# Mnd                                                                      ...
# 2008-06-30  26.0   17.6  28.9  6.9  5.3  6.1      5.9  0.0   1.8    0.0  ...
# 2008-07-31  26.9   17.2  30.2  6.6  4.7  6.1      5.4  0.0   1.9    0.0  ...
# 2008-08-31  26.6   16.2  30.9  6.7  5.2  5.5      6.0  0.0   1.7    0.0  ...
# 2008-09-30  28.9   15.2  29.9  6.3  5.0  5.7      5.9  0.0   1.5    0.0  ...
# 2008-10-31  30.6   16.1  26.7  7.3  5.3  5.6      5.5  0.0   1.2    0.0  ...
# ...          ...    ...   ...  ...  ...  ...      ...  ...   ...    ...  ...
# 2025-03-31  28.1   18.8  22.7  7.2  4.9  3.1      4.3  2.7   4.6    3.4  ...
# 2025-04-30  28.1   19.8  20.0  6.3  6.7  3.3      3.9  3.1   4.8    3.9  ...
# 2025-05-31  28.5   18.7  20.6  7.0  5.7  3.6      4.1  2.7   5.3    3.8  ...
# 2025-06-30  28.3   16.2  21.0  6.9  5.6  3.7      4.5  3.0   6.2    4.5  ...
# 2025-07-31  27.5   14.8  21.5  8.2  6.3  3.2      4.7  3.5   5.9    4.1  ...
#
#             Rodt_reg_lag3  Rodt_reg_lag6  Andre_reg_lag3  Andre_reg_lag6  \
# Mnd
# 2008-06-30            0.0            0.0             0.0             0.0
# 2008-07-31            0.0            0.0             0.0             0.0
# 2008-08-31            0.0            0.0             0.0             0.0
# 2008-09-30            0.0            0.0             0.0             0.0
# 2008-10-31            0.0            0.0             0.0             0.0
# ...                   ...            ...             ...             ...
# 2025-03-31            0.0            0.0             0.0             0.0
# 2025-04-30            0.0            0.0             0.0             0.0
# 2025-05-31            0.0            0.0             0.0             0.0
# 2025-06-30            0.0            0.0             0.0             0.0
# 2025-07-31            0.0            0.0             0.0             0.0
#
#             ledighet  ledig_trend3  ledig_trend6  styringsrente  \
# Mnd
# 2008-06-30       2.9         0.067      0.050000           5.54
# 2008-07-31       2.9         0.033      0.050000           5.75
# 2008-08-31       3.0         0.033      0.066667           5.75
# 2008-09-30       3.1         0.067      0.066667           5.75
# 2008-10-31       3.1         0.033      0.050000           5.45
# ...              ...           ...           ...            ...
# 2025-03-31       4.0        -0.033      0.000000           4.50
# 2025-04-30       4.0        -0.033     -0.016667           4.20
# 2025-05-31       4.0         0.000     -0.016667           4.20
# 2025-06-30       4.0         0.000     -0.016667           4.20
# 2025-07-31       4.0         0.000     -0.016667           4.00
#
#             styringsrente_trend3  styringsrente_trend6
# Mnd
# 2008-06-30              0.076667              0.048333
# 2008-07-31              0.083333              0.083333
# 2008-08-31              0.070000              0.083333
# 2008-09-30              0.000000              0.073333
# 2008-10-31             -0.100000             -0.008333
# ...                          ...                   ...
# 2025-03-31              0.000000              0.000000
# 2025-04-30             -0.100000             -0.050000
# 2025-05-31             -0.100000             -0.050000
# 2025-06-30              0.000000             -0.050000
# 2025-07-31             -0.066667             -0.083333
#
# [206 rows x 76 columns]

# %%
df_en=df[['Ap', 'Hoyre', 'Frp', 'SV', 'SP', 'KrF', 'Venstre', 'MDG', 'Rodt','Andre']]
df_en = df_en.diff().dropna()  # Difference to make stationary
df_orig=df

# %%
df_ex=df[[
       'Ap_skandale_lag6', 'Hoyre_skandale_lag6', 'Frp_skandale_lag6',
       'SV_skandale_lag6', 'SP_skandale_lag6', 'KrF_skandale_lag6',
       #'Venstre_skandale_lag6', 
        #'MDG_skandale_lag6', 
        'Rodt_skandale_lag6',
       #'Andre_skandale_lag6', 
       # 'Ap_reg', 'Hoyre_reg', 'Frp_reg', 'SV_reg',
       #'SP_reg', 'KrF_reg', 'Venstre_reg', 'MDG_reg', 'Rodt_reg', 'Andre_reg',
       #'Ap_reg_lag3', 
       'Ap_reg_lag6',
        'Hoyre_reg_lag6', 
       # 'Frp_reg_lag6','SV_reg_lag6', 
       # 'SP_reg_lag6','KrF_reg_lag6',
       # 'Venstre_reg_lag6', 
        #'MDG_reg_lag6',
        #'Rodt_reg_lag6', 
        #'Andre_reg_lag6',
       'ledighet', 'ledig_trend3', 'ledig_trend6', 'styringsrente',
       'styringsrente_trend3', 'styringsrente_trend6']].iloc[1:]

# %%
df_ex
# Out:
#             Ap_skandale_lag6  Hoyre_skandale_lag6  Frp_skandale_lag6  \
# Mnd
# 2008-07-31               1.0                  0.0                0.0
# 2008-08-31               0.0                  0.0                0.0
# 2008-09-30               0.0                  0.0                0.0
# 2008-10-31               1.0                  0.0                0.0
# 2008-11-30               1.0                  0.0                0.0
# ...                      ...                  ...                ...
# 2025-03-31               0.0                  0.0                0.0
# 2025-04-30               0.0                  0.0                0.0
# 2025-05-31               0.0                  0.0                0.0
# 2025-06-30               0.0                  0.0                0.0
# 2025-07-31               0.0                  0.0                0.0
#
#             SV_skandale_lag6  SP_skandale_lag6  KrF_skandale_lag6  \
# Mnd
# 2008-07-31               0.0               1.0                0.0
# 2008-08-31               0.0               1.0                0.0
# 2008-09-30               0.0               1.0                0.0
# 2008-10-31               0.0               1.0                0.0
# 2008-11-30               0.0               1.0                0.0
# ...                      ...               ...                ...
# 2025-03-31               0.0               0.0                0.0
# 2025-04-30               0.0               0.0                0.0
# 2025-05-31               0.0               0.0                0.0
# 2025-06-30               0.0               0.0                0.0
# 2025-07-31               0.0               0.0                0.0
#
#             Rodt_skandale_lag6  Ap_reg_lag6  Hoyre_reg_lag6  ledighet  \
# Mnd
# 2008-07-31                 0.0          6.0             0.0       2.9
# 2008-08-31                 0.0          6.0             0.0       3.0
# 2008-09-30                 0.0          6.0             0.0       3.1
# 2008-10-31                 0.0          6.0             0.0       3.1
# 2008-11-30                 0.0          6.0             0.0       3.1
# ...                        ...          ...             ...       ...
# 2025-03-31                 0.0          6.0             0.0       4.0
# 2025-04-30                 0.0          6.0             0.0       4.0
# 2025-05-31                 0.0          6.0             0.0       4.0
# 2025-06-30                 0.0          6.0             0.0       4.0
# 2025-07-31                 0.0          6.0             0.0       4.0
#
#             ledig_trend3  ledig_trend6  styringsrente  styringsrente_trend3  \
# Mnd
# 2008-07-31         0.033      0.050000           5.75              0.083333
# 2008-08-31         0.033      0.066667           5.75              0.070000
# 2008-09-30         0.067      0.066667           5.75              0.000000
# 2008-10-31         0.033      0.050000           5.45             -0.100000
# 2008-11-30         0.000      0.033333           4.75             -0.333333
# ...                  ...           ...            ...                   ...
# 2025-03-31        -0.033      0.000000           4.50              0.000000
# 2025-04-30        -0.033     -0.016667           4.20             -0.100000
# 2025-05-31         0.000     -0.016667           4.20             -0.100000
# 2025-06-30         0.000     -0.016667           4.20              0.000000
# 2025-07-31         0.000     -0.016667           4.00             -0.066667
#
#             styringsrente_trend6
# Mnd
# 2008-07-31              0.083333
# 2008-08-31              0.083333
# 2008-09-30              0.073333
# 2008-10-31             -0.008333
# 2008-11-30             -0.131667
# ...                          ...
# 2025-03-31              0.000000
# 2025-04-30             -0.050000
# 2025-05-31             -0.050000
# 2025-06-30             -0.050000
# 2025-07-31             -0.083333
#
# [205 rows x 15 columns]

# %%
model = VAR(endog=df_en, exog=df_ex)
#model = VAR(df_en)
model_fitted = model.fit(maxlags=3,method = 'ols', trend='n', verbose=True)

print(model_fitted.summary())
# Out:
# C:\Users\jens.nilsen\python\WPy64-31230\python-3.12.3.amd64\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 15, Jul, 2025
# Time:                     12:43:19
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -5.23074
# Nobs:                     202.000    HQIC:                  -9.61877
# Log likelihood:          -1143.59    FPE:                3.63586e-06
# AIC:                     -12.6006    Det(Omega_mle):     4.86577e-07
# --------------------------------------------------------------------
# Results for equation Ap
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6            -0.117826         0.242825           -0.485           0.628
# Hoyre_skandale_lag6          0.027089         0.255186            0.106           0.915
# Frp_skandale_lag6            0.106252         0.200727            0.529           0.597
# SV_skandale_lag6            -0.641209         0.684540           -0.937           0.349
# SP_skandale_lag6            -0.220667         0.327191           -0.674           0.500
# KrF_skandale_lag6            0.046829         0.845862            0.055           0.956
# Rodt_skandale_lag6           0.140150         0.635874            0.220           0.826
# Ap_reg_lag6                  0.033637         0.223873            0.150           0.881
# Hoyre_reg_lag6               0.045943         0.252923            0.182           0.856
# ledighet                    -0.111227         0.335872           -0.331           0.741
# ledig_trend3                -0.637288         3.112671           -0.205           0.838
# ledig_trend6                -0.974098         3.319753           -0.293           0.769
# styringsrente                0.174427         0.157430            1.108           0.268
# styringsrente_trend3        -1.468912         2.438592           -0.602           0.547
# styringsrente_trend6         0.721769         2.261598            0.319           0.750
# L1.Ap                       -1.370590         0.452285           -3.030           0.002
# L1.Hoyre                    -1.354217         0.457371           -2.961           0.003
# L1.Frp                      -1.387359         0.453958           -3.056           0.002
# L1.SV                       -1.428468         0.520324           -2.745           0.006
# L1.SP                       -1.232343         0.453368           -2.718           0.007
# L1.KrF                      -1.042429         0.550762           -1.893           0.058
# L1.Venstre                  -1.429676         0.562394           -2.542           0.011
# L1.MDG                      -1.960214         0.557464           -3.516           0.000
# L1.Rodt                     -1.423126         0.485762           -2.930           0.003
# L1.Andre                    -1.490871         0.482413           -3.090           0.002
# L2.Ap                       -0.114498         0.468506           -0.244           0.807
# L2.Hoyre                     0.010712         0.477242            0.022           0.982
# L2.Frp                      -0.038279         0.471257           -0.081           0.935
# L2.SV                       -0.398885         0.561891           -0.710           0.478
# L2.SP                        0.050144         0.469430            0.107           0.915
# L2.KrF                       0.995562         0.584023            1.705           0.088
# L2.Venstre                  -0.219827         0.616332           -0.357           0.721
# L2.MDG                       0.209809         0.606595            0.346           0.729
# L2.Rodt                      0.249436         0.495333            0.504           0.615
# L2.Andre                    -0.102594         0.518259           -0.198           0.843
# L3.Ap                       -0.206970         0.447408           -0.463           0.644
# L3.Hoyre                    -0.193960         0.460142           -0.422           0.673
# L3.Frp                      -0.133282         0.452862           -0.294           0.769
# L3.SV                       -0.434529         0.537208           -0.809           0.419
# L3.SP                       -0.057436         0.455256           -0.126           0.900
# L3.KrF                       0.303929         0.544278            0.558           0.577
# L3.Venstre                   0.134990         0.563619            0.240           0.811
# L3.MDG                      -0.313734         0.569069           -0.551           0.581
# L3.Rodt                     -0.095117         0.479046           -0.199           0.843
# L3.Andre                    -0.377307         0.492264           -0.766           0.443
# =======================================================================================
#
# Results for equation Hoyre
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6            -0.328135         0.199747           -1.643           0.100
# Hoyre_skandale_lag6         -0.224592         0.209914           -1.070           0.285
# Frp_skandale_lag6           -0.094028         0.165117           -0.569           0.569
# SV_skandale_lag6             0.515072         0.563099            0.915           0.360
# SP_skandale_lag6            -0.154020         0.269145           -0.572           0.567
# KrF_skandale_lag6            0.515168         0.695802            0.740           0.459
# Rodt_skandale_lag6           0.351963         0.523067            0.673           0.501
# Ap_reg_lag6                  0.443765         0.184157            2.410           0.016
# Hoyre_reg_lag6               0.350024         0.208053            1.682           0.092
# ledighet                    -0.406407         0.276287           -1.471           0.141
# ledig_trend3                 5.415658         2.560469            2.115           0.034
# ledig_trend6                -1.010030         2.730813           -0.370           0.711
# styringsrente               -0.391850         0.129501           -3.026           0.002
# styringsrente_trend3        -4.087045         2.005974           -2.037           0.042
# styringsrente_trend6         3.733319         1.860380            2.007           0.045
# L1.Ap                        1.030494         0.372048            2.770           0.006
# L1.Hoyre                     0.999196         0.376232            2.656           0.008
# L1.Frp                       0.993037         0.373423            2.659           0.008
# L1.SV                        1.281197         0.428016            2.993           0.003
# L1.SP                        1.031998         0.372939            2.767           0.006
# L1.KrF                       1.145502         0.453054            2.528           0.011
# L1.Venstre                   1.069507         0.462623            2.312           0.021
# L1.MDG                       0.893101         0.458567            1.948           0.051
# L1.Rodt                      1.202922         0.399585            3.010           0.003
# L1.Andre                     0.729563         0.396831            1.838           0.066
# L2.Ap                       -0.299033         0.385391           -0.776           0.438
# L2.Hoyre                    -0.603138         0.392577           -1.536           0.124
# L2.Frp                      -0.317970         0.387653           -0.820           0.412
# L2.SV                        0.031482         0.462209            0.068           0.946
# L2.SP                       -0.300809         0.386151           -0.779           0.436
# L2.KrF                      -0.893860         0.480415           -1.861           0.063
# L2.Venstre                  -0.041489         0.506992           -0.082           0.935
# L2.MDG                      -0.867478         0.498982           -1.738           0.082
# L2.Rodt                     -0.192841         0.407459           -0.473           0.636
# L2.Andre                    -0.161976         0.426318           -0.380           0.704
# L3.Ap                        0.339020         0.368035            0.921           0.357
# L3.Hoyre                     0.340906         0.378510            0.901           0.368
# L3.Frp                       0.441771         0.372522            1.186           0.236
# L3.SV                        0.170653         0.441905            0.386           0.699
# L3.SP                        0.120807         0.374491            0.323           0.747
# L3.KrF                       0.379861         0.447721            0.848           0.396
# L3.Venstre                   0.363308         0.463630            0.784           0.433
# L3.MDG                      -0.298852         0.468114           -0.638           0.523
# L3.Rodt                      0.513923         0.394061            1.304           0.192
# L3.Andre                     0.497958         0.404934            1.230           0.219
# =======================================================================================
#
# Results for equation Frp
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.217485         0.185898            1.170           0.242
# Hoyre_skandale_lag6          0.264247         0.195361            1.353           0.176
# Frp_skandale_lag6           -0.210217         0.153669           -1.368           0.171
# SV_skandale_lag6             0.391428         0.524058            0.747           0.455
# SP_skandale_lag6             0.293818         0.250485            1.173           0.241
# KrF_skandale_lag6            0.000092         0.647561            0.000           1.000
# Rodt_skandale_lag6          -0.084332         0.486802           -0.173           0.862
# Ap_reg_lag6                 -0.276588         0.171389           -1.614           0.107
# Hoyre_reg_lag6              -0.202031         0.193629           -1.043           0.297
# ledighet                     0.216468         0.257132            0.842           0.400
# ledig_trend3                -5.442851         2.382947           -2.284           0.022
# ledig_trend6                 2.194538         2.541481            0.863           0.388
# styringsrente                0.255353         0.120523            2.119           0.034
# styringsrente_trend3         5.780206         1.866897            3.096           0.002
# styringsrente_trend6        -5.490283         1.731397           -3.171           0.002
# L1.Ap                        0.273294         0.346253            0.789           0.430
# L1.Hoyre                     0.377753         0.350147            1.079           0.281
# L1.Frp                       0.249426         0.347533            0.718           0.473
# L1.SV                        0.281916         0.398341            0.708           0.479
# L1.SP                        0.305417         0.347082            0.880           0.379
# L1.KrF                       0.457381         0.421643            1.085           0.278
# L1.Venstre                   0.537331         0.430548            1.248           0.212
# L1.MDG                       0.016818         0.426774            0.039           0.969
# L1.Rodt                      0.405139         0.371882            1.089           0.276
# L1.Andre                     0.347651         0.369318            0.941           0.347
# L2.Ap                       -0.249632         0.358671           -0.696           0.486
# L2.Hoyre                     0.021843         0.365359            0.060           0.952
# L2.Frp                      -0.322580         0.360777           -0.894           0.371
# L2.SV                       -0.290702         0.430163           -0.676           0.499
# L2.SP                       -0.325884         0.359379           -0.907           0.365
# L2.KrF                      -0.040639         0.447107           -0.091           0.928
# L2.Venstre                   0.040024         0.471841            0.085           0.932
# L2.MDG                      -0.073316         0.464387           -0.158           0.875
# L2.Rodt                     -0.277021         0.379209           -0.731           0.465
# L2.Andre                    -0.651623         0.396760           -1.642           0.101
# L3.Ap                       -0.416728         0.342519           -1.217           0.224
# L3.Hoyre                    -0.337958         0.352268           -0.959           0.337
# L3.Frp                      -0.433898         0.346694           -1.252           0.211
# L3.SV                       -0.466046         0.411267           -1.133           0.257
# L3.SP                       -0.289383         0.348527           -0.830           0.406
# L3.KrF                      -0.561042         0.416679           -1.346           0.178
# L3.Venstre                  -0.507521         0.431486           -1.176           0.240
# L3.MDG                       0.297275         0.435659            0.682           0.495
# L3.Rodt                     -0.004879         0.366740           -0.013           0.989
# L3.Andre                    -0.534028         0.376859           -1.417           0.156
# =======================================================================================
#
# Results for equation SV
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.183126         0.073144            2.504           0.012
# Hoyre_skandale_lag6         -0.077379         0.076867           -1.007           0.314
# Frp_skandale_lag6           -0.067387         0.060463           -1.115           0.265
# SV_skandale_lag6             0.141847         0.206197            0.688           0.492
# SP_skandale_lag6             0.181809         0.098556            1.845           0.065
# KrF_skandale_lag6           -0.233364         0.254790           -0.916           0.360
# Rodt_skandale_lag6          -0.263939         0.191538           -1.378           0.168
# Ap_reg_lag6                 -0.010513         0.067435           -0.156           0.876
# Hoyre_reg_lag6               0.044942         0.076185            0.590           0.555
# ledighet                    -0.036766         0.101171           -0.363           0.716
# ledig_trend3                -0.867489         0.937598           -0.925           0.355
# ledig_trend6                 0.457977         0.999975            0.458           0.647
# styringsrente                0.018403         0.047421            0.388           0.698
# styringsrente_trend3        -0.627245         0.734552           -0.854           0.393
# styringsrente_trend6         0.254091         0.681238            0.373           0.709
# L1.Ap                        0.147418         0.136237            1.082           0.279
# L1.Hoyre                     0.127693         0.137769            0.927           0.354
# L1.Frp                       0.159951         0.136741            1.170           0.242
# L1.SV                       -0.211131         0.156732           -1.347           0.178
# L1.SP                        0.161879         0.136563            1.185           0.236
# L1.KrF                       0.006795         0.165900            0.041           0.967
# L1.Venstre                   0.427054         0.169404            2.521           0.012
# L1.MDG                       0.516330         0.167919            3.075           0.002
# L1.Rodt                      0.245597         0.146321            1.678           0.093
# L1.Andre                     0.242896         0.145312            1.672           0.095
# L2.Ap                        0.400029         0.141123            2.835           0.005
# L2.Hoyre                     0.397838         0.143755            2.767           0.006
# L2.Frp                       0.391444         0.141952            2.758           0.006
# L2.SV                        0.310276         0.169253            1.833           0.067
# L2.SP                        0.323129         0.141402            2.285           0.022
# L2.KrF                       0.141885         0.175919            0.807           0.420
# L2.Venstre                   0.702427         0.185651            3.784           0.000
# L2.MDG                       0.452887         0.182718            2.479           0.013
# L2.Rodt                      0.306017         0.149204            2.051           0.040
# L2.Andre                     0.335595         0.156110            2.150           0.032
# L3.Ap                        0.170737         0.134768            1.267           0.205
# L3.Hoyre                     0.134808         0.138604            0.973           0.331
# L3.Frp                       0.145971         0.136411            1.070           0.285
# L3.SV                        0.180005         0.161818            1.112           0.266
# L3.SP                        0.121528         0.137132            0.886           0.376
# L3.KrF                       0.031985         0.163947            0.195           0.845
# L3.Venstre                   0.392631         0.169773            2.313           0.021
# L3.MDG                       0.106808         0.171415            0.623           0.533
# L3.Rodt                      0.052516         0.144298            0.364           0.716
# L3.Andre                     0.081290         0.148280            0.548           0.584
# =======================================================================================
#
# Results for equation SP
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.021345         0.148371            0.144           0.886
# Hoyre_skandale_lag6         -0.257794         0.155923           -1.653           0.098
# Frp_skandale_lag6            0.227416         0.122648            1.854           0.064
# SV_skandale_lag6            -0.086228         0.418266           -0.206           0.837
# SP_skandale_lag6            -0.147700         0.199919           -0.739           0.460
# KrF_skandale_lag6           -1.238848         0.516837           -2.397           0.017
# Rodt_skandale_lag6          -0.232023         0.388530           -0.597           0.550
# Ap_reg_lag6                 -0.233839         0.136791           -1.709           0.087
# Hoyre_reg_lag6              -0.204047         0.154540           -1.320           0.187
# ledighet                     0.303137         0.205224            1.477           0.140
# ledig_trend3                -0.221058         1.901897           -0.116           0.907
# ledig_trend6                -0.365845         2.028428           -0.180           0.857
# styringsrente                0.123271         0.096192            1.282           0.200
# styringsrente_trend3         1.561008         1.490023            1.048           0.295
# styringsrente_trend6        -0.667054         1.381877           -0.483           0.629
# L1.Ap                        0.000316         0.276354            0.001           0.999
# L1.Hoyre                     0.059662         0.279462            0.213           0.831
# L1.Frp                       0.040988         0.277376            0.148           0.883
# L1.SV                        0.092663         0.317927            0.291           0.771
# L1.SP                       -0.155291         0.277016           -0.561           0.575
# L1.KrF                       0.299862         0.336525            0.891           0.373
# L1.Venstre                  -0.078482         0.343633           -0.228           0.819
# L1.MDG                       0.280896         0.340620            0.825           0.410
# L1.Rodt                     -0.313359         0.296809           -1.056           0.291
# L1.Andre                     0.027153         0.294763            0.092           0.927
# L2.Ap                       -0.314010         0.286266           -1.097           0.273
# L2.Hoyre                    -0.285732         0.291603           -0.980           0.327
# L2.Frp                      -0.216144         0.287946           -0.751           0.453
# L2.SV                       -0.050599         0.343325           -0.147           0.883
# L2.SP                       -0.432580         0.286830           -1.508           0.132
# L2.KrF                      -0.163771         0.356848           -0.459           0.646
# L2.Venstre                  -0.516002         0.376590           -1.370           0.171
# L2.MDG                      -0.270400         0.370640           -0.730           0.466
# L2.Rodt                     -0.484623         0.302657           -1.601           0.109
# L2.Andre                    -0.194154         0.316666           -0.613           0.540
# L3.Ap                       -0.175155         0.273374           -0.641           0.522
# L3.Hoyre                    -0.168714         0.281155           -0.600           0.548
# L3.Frp                      -0.227648         0.276707           -0.823           0.411
# L3.SV                        0.071749         0.328244            0.219           0.827
# L3.SP                       -0.321472         0.278169           -1.156           0.248
# L3.KrF                      -0.195465         0.332564           -0.588           0.557
# L3.Venstre                  -0.529007         0.344381           -1.536           0.125
# L3.MDG                       0.133260         0.347711            0.383           0.702
# L3.Rodt                     -0.491484         0.292705           -1.679           0.093
# L3.Andre                    -0.112334         0.300782           -0.373           0.709
# =======================================================================================
#
# Results for equation KrF
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.057385         0.055327            1.037           0.300
# Hoyre_skandale_lag6          0.036091         0.058143            0.621           0.535
# Frp_skandale_lag6            0.011591         0.045735            0.253           0.800
# SV_skandale_lag6            -0.098085         0.155969           -0.629           0.529
# SP_skandale_lag6            -0.046908         0.074549           -0.629           0.529
# KrF_skandale_lag6           -0.007909         0.192725           -0.041           0.967
# Rodt_skandale_lag6          -0.190174         0.144881           -1.313           0.189
# Ap_reg_lag6                 -0.020402         0.051008           -0.400           0.689
# Hoyre_reg_lag6              -0.029863         0.057627           -0.518           0.604
# ledighet                     0.019631         0.076527            0.257           0.798
# ledig_trend3                 0.210556         0.709206            0.297           0.767
# ledig_trend6                 0.449257         0.756389            0.594           0.553
# styringsrente                0.019642         0.035870            0.548           0.584
# styringsrente_trend3        -0.096523         0.555621           -0.174           0.862
# styringsrente_trend6         0.080807         0.515293            0.157           0.875
# L1.Ap                        0.065211         0.103051            0.633           0.527
# L1.Hoyre                     0.021583         0.104210            0.207           0.836
# L1.Frp                       0.030088         0.103432            0.291           0.771
# L1.SV                        0.122033         0.118553            1.029           0.303
# L1.SP                        0.014135         0.103298            0.137           0.891
# L1.KrF                      -0.632549         0.125488           -5.041           0.000
# L1.Venstre                   0.107910         0.128139            0.842           0.400
# L1.MDG                       0.129114         0.127015            1.017           0.309
# L1.Rodt                      0.030206         0.110678            0.273           0.785
# L1.Andre                     0.151106         0.109915            1.375           0.169
# L2.Ap                        0.127896         0.106747            1.198           0.231
# L2.Hoyre                     0.092712         0.108737            0.853           0.394
# L2.Frp                       0.095626         0.107373            0.891           0.373
# L2.SV                        0.051356         0.128024            0.401           0.688
# L2.SP                        0.111912         0.106957            1.046           0.295
# L2.KrF                      -0.308899         0.133067           -2.321           0.020
# L2.Venstre                   0.232870         0.140428            1.658           0.097
# L2.MDG                       0.153786         0.138210            1.113           0.266
# L2.Rodt                      0.172838         0.112859            1.531           0.126
# L2.Andre                     0.172709         0.118083            1.463           0.144
# L3.Ap                       -0.053400         0.101940           -0.524           0.600
# L3.Hoyre                    -0.063721         0.104841           -0.608           0.543
# L3.Frp                      -0.053311         0.103182           -0.517           0.605
# L3.SV                        0.005790         0.122400            0.047           0.962
# L3.SP                       -0.043567         0.103728           -0.420           0.674
# L3.KrF                      -0.344372         0.124011           -2.777           0.005
# L3.Venstre                   0.062099         0.128418            0.484           0.629
# L3.MDG                      -0.165990         0.129659           -1.280           0.200
# L3.Rodt                     -0.108852         0.109148           -0.997           0.319
# L3.Andre                    -0.025799         0.112160           -0.230           0.818
# =======================================================================================
#
# Results for equation Venstre
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.068370         0.067187            1.018           0.309
# Hoyre_skandale_lag6          0.034081         0.070607            0.483           0.629
# Frp_skandale_lag6           -0.021023         0.055539           -0.379           0.705
# SV_skandale_lag6            -0.155595         0.189405           -0.821           0.411
# SP_skandale_lag6            -0.038306         0.090530           -0.423           0.672
# KrF_skandale_lag6            0.031570         0.234041            0.135           0.893
# Rodt_skandale_lag6           0.118282         0.175940            0.672           0.501
# Ap_reg_lag6                 -0.053982         0.061943           -0.871           0.383
# Hoyre_reg_lag6              -0.078950         0.069981           -1.128           0.259
# ledighet                     0.105487         0.092932            1.135           0.256
# ledig_trend3                -0.301028         0.861244           -0.350           0.727
# ledig_trend6                -0.725417         0.918541           -0.790           0.430
# styringsrente               -0.037741         0.043559           -0.866           0.386
# styringsrente_trend3        -0.512626         0.674733           -0.760           0.447
# styringsrente_trend6         0.504482         0.625761            0.806           0.420
# L1.Ap                       -0.131180         0.125143           -1.048           0.295
# L1.Hoyre                    -0.185574         0.126550           -1.466           0.143
# L1.Frp                      -0.153431         0.125605           -1.222           0.222
# L1.SV                       -0.126626         0.143968           -0.880           0.379
# L1.SP                       -0.169964         0.125442           -1.355           0.175
# L1.KrF                      -0.183950         0.152390           -1.207           0.227
# L1.Venstre                  -0.634626         0.155609           -4.078           0.000
# L1.MDG                       0.019785         0.154244            0.128           0.898
# L1.Rodt                     -0.198088         0.134405           -1.474           0.141
# L1.Andre                    -0.098630         0.133479           -0.739           0.460
# L2.Ap                        0.197872         0.129631            1.526           0.127
# L2.Hoyre                     0.191031         0.132048            1.447           0.148
# L2.Frp                       0.218987         0.130392            1.679           0.093
# L2.SV                        0.173630         0.155469            1.117           0.264
# L2.SP                        0.148646         0.129886            1.144           0.252
# L2.KrF                       0.055271         0.161593            0.342           0.732
# L2.Venstre                  -0.048873         0.170533           -0.287           0.774
# L2.MDG                       0.330265         0.167839            1.968           0.049
# L2.Rodt                      0.194181         0.137054            1.417           0.157
# L2.Andre                     0.254750         0.143397            1.777           0.076
# L3.Ap                        0.124342         0.123793            1.004           0.315
# L3.Hoyre                     0.104978         0.127316            0.825           0.410
# L3.Frp                       0.106213         0.125302            0.848           0.397
# L3.SV                        0.215551         0.148640            1.450           0.147
# L3.SP                        0.135943         0.125964            1.079           0.280
# L3.KrF                       0.119474         0.150596            0.793           0.428
# L3.Venstre                   0.059461         0.155948            0.381           0.703
# L3.MDG                       0.234987         0.157456            1.492           0.136
# L3.Rodt                      0.109770         0.132547            0.828           0.408
# L3.Andre                     0.207945         0.136204            1.527           0.127
# =======================================================================================
#
# Results for equation MDG
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6            -0.048411         0.056314           -0.860           0.390
# Hoyre_skandale_lag6          0.055963         0.059181            0.946           0.344
# Frp_skandale_lag6           -0.021706         0.046551           -0.466           0.641
# SV_skandale_lag6            -0.053871         0.158754           -0.339           0.734
# SP_skandale_lag6            -0.020598         0.075880           -0.271           0.786
# KrF_skandale_lag6           -0.395265         0.196167           -2.015           0.044
# Rodt_skandale_lag6           0.100528         0.147468            0.682           0.495
# Ap_reg_lag6                  0.111327         0.051919            2.144           0.032
# Hoyre_reg_lag6               0.109334         0.058656            1.864           0.062
# ledighet                    -0.144611         0.077893           -1.857           0.063
# ledig_trend3                 0.419074         0.721870            0.581           0.562
# ledig_trend6                -0.026096         0.769895           -0.034           0.973
# styringsrente               -0.037549         0.036510           -1.028           0.304
# styringsrente_trend3        -0.078461         0.565542           -0.139           0.890
# styringsrente_trend6         0.218637         0.524495            0.417           0.677
# L1.Ap                       -0.119566         0.104891           -1.140           0.254
# L1.Hoyre                    -0.103946         0.106071           -0.980           0.327
# L1.Frp                      -0.090906         0.105279           -0.863           0.388
# L1.SV                       -0.162220         0.120670           -1.344           0.179
# L1.SP                       -0.142598         0.105142           -1.356           0.175
# L1.KrF                      -0.149591         0.127729           -1.171           0.242
# L1.Venstre                  -0.062185         0.130427           -0.477           0.634
# L1.MDG                      -0.268722         0.129283           -2.079           0.038
# L1.Rodt                      0.057828         0.112655            0.513           0.608
# L1.Andre                    -0.008584         0.111878           -0.077           0.939
# L2.Ap                       -0.051538         0.108653           -0.474           0.635
# L2.Hoyre                    -0.100799         0.110679           -0.911           0.362
# L2.Frp                      -0.080151         0.109291           -0.733           0.463
# L2.SV                       -0.124346         0.130310           -0.954           0.340
# L2.SP                        0.008693         0.108867            0.080           0.936
# L2.KrF                      -0.097044         0.135443           -0.716           0.474
# L2.Venstre                  -0.140803         0.142936           -0.985           0.325
# L2.MDG                      -0.138932         0.140678           -0.988           0.323
# L2.Rodt                     -0.076508         0.114874           -0.666           0.505
# L2.Andre                     0.059643         0.120191            0.496           0.620
# L3.Ap                        0.049325         0.103760            0.475           0.635
# L3.Hoyre                     0.045185         0.106713            0.423           0.672
# L3.Frp                       0.009295         0.105025            0.089           0.929
# L3.SV                        0.001689         0.124586            0.014           0.989
# L3.SP                        0.051032         0.105580            0.483           0.629
# L3.KrF                       0.092030         0.126225            0.729           0.466
# L3.Venstre                  -0.019207         0.130711           -0.147           0.883
# L3.MDG                       0.051628         0.131975            0.391           0.696
# L3.Rodt                      0.070560         0.111097            0.635           0.525
# L3.Andre                     0.155978         0.114163            1.366           0.172
# =======================================================================================
#
# Results for equation Rodt
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6            -0.096732         0.072415           -1.336           0.182
# Hoyre_skandale_lag6          0.202029         0.076101            2.655           0.008
# Frp_skandale_lag6            0.089976         0.059860            1.503           0.133
# SV_skandale_lag6            -0.053224         0.204141           -0.261           0.794
# SP_skandale_lag6             0.094831         0.097574            0.972           0.331
# KrF_skandale_lag6            1.167369         0.252250            4.628           0.000
# Rodt_skandale_lag6          -0.113307         0.189628           -0.598           0.550
# Ap_reg_lag6                 -0.094703         0.066763           -1.418           0.156
# Hoyre_reg_lag6              -0.127741         0.075426           -1.694           0.090
# ledighet                     0.159075         0.100163            1.588           0.112
# ledig_trend3                 0.973522         0.928252            1.049           0.294
# ledig_trend6                -0.437525         0.990007           -0.442           0.659
# styringsrente               -0.022850         0.046948           -0.487           0.626
# styringsrente_trend3         0.628892         0.727230            0.865           0.387
# styringsrente_trend6        -0.112038         0.674447           -0.166           0.868
# L1.Ap                        0.068253         0.134879            0.506           0.613
# L1.Hoyre                     0.049563         0.136396            0.363           0.716
# L1.Frp                       0.091793         0.135378            0.678           0.498
# L1.SV                        0.062545         0.155170            0.403           0.687
# L1.SP                        0.070972         0.135202            0.525           0.600
# L1.KrF                       0.022247         0.164247            0.135           0.892
# L1.Venstre                  -0.074080         0.167716           -0.442           0.659
# L1.MDG                       0.289004         0.166245            1.738           0.082
# L1.Rodt                     -0.250282         0.144862           -1.728           0.084
# L1.Andre                     0.219295         0.143864            1.524           0.127
# L2.Ap                        0.031184         0.139717            0.223           0.823
# L2.Hoyre                     0.061971         0.142322            0.435           0.663
# L2.Frp                       0.010752         0.140537            0.077           0.939
# L2.SV                        0.208458         0.167566            1.244           0.213
# L2.SP                        0.077883         0.139992            0.556           0.578
# L2.KrF                      -0.100020         0.174166           -0.574           0.566
# L2.Venstre                  -0.198001         0.183801           -1.077           0.281
# L2.MDG                       0.211006         0.180897            1.166           0.243
# L2.Rodt                     -0.227445         0.147717           -1.540           0.124
# L2.Andre                    -0.092905         0.154554           -0.601           0.548
# L3.Ap                        0.031967         0.133425            0.240           0.811
# L3.Hoyre                     0.042182         0.137222            0.307           0.759
# L3.Frp                       0.011753         0.135051            0.087           0.931
# L3.SV                        0.174612         0.160205            1.090           0.276
# L3.SP                        0.058596         0.135765            0.432           0.666
# L3.KrF                      -0.153664         0.162313           -0.947           0.344
# L3.Venstre                  -0.068076         0.168081           -0.405           0.685
# L3.MDG                      -0.013224         0.169706           -0.078           0.938
# L3.Rodt                     -0.118891         0.142860           -0.832           0.405
# L3.Andre                    -0.027373         0.146802           -0.186           0.852
# =======================================================================================
#
# Results for equation Andre
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# Ap_skandale_lag6             0.031309         0.062023            0.505           0.614
# Hoyre_skandale_lag6          0.002377         0.065180            0.036           0.971
# Frp_skandale_lag6           -0.027289         0.051270           -0.532           0.595
# SV_skandale_lag6             0.031472         0.174848            0.180           0.857
# SP_skandale_lag6             0.070497         0.083572            0.844           0.399
# KrF_skandale_lag6            0.114307         0.216053            0.529           0.597
# Rodt_skandale_lag6           0.201703         0.162417            1.242           0.214
# Ap_reg_lag6                  0.090257         0.057183            1.578           0.114
# Hoyre_reg_lag6               0.059297         0.064603            0.918           0.359
# ledighet                    -0.055240         0.085790           -0.644           0.520
# ledig_trend3                 0.739324         0.795051            0.930           0.352
# ledig_trend6                 0.421188         0.847944            0.497           0.619
# styringsrente               -0.148837         0.040211           -3.701           0.000
# styringsrente_trend3        -0.706617         0.622875           -1.134           0.257
# styringsrente_trend6         0.978229         0.577666            1.693           0.090
# L1.Ap                       -0.217028         0.115524           -1.879           0.060
# L1.Hoyre                    -0.253864         0.116824           -2.173           0.030
# L1.Frp                      -0.218122         0.115952           -1.881           0.060
# L1.SV                       -0.287417         0.132903           -2.163           0.031
# L1.SP                       -0.164180         0.115801           -1.418           0.156
# L1.KrF                      -0.342891         0.140678           -2.437           0.015
# L1.Venstre                  -0.191137         0.143649           -1.331           0.183
# L1.MDG                      -0.260277         0.142389           -1.828           0.068
# L1.Rodt                     -0.003806         0.124075           -0.031           0.976
# L1.Andre                    -0.417696         0.123220           -3.390           0.001
# L2.Ap                       -0.009702         0.119668           -0.081           0.935
# L2.Hoyre                    -0.049518         0.121899           -0.406           0.685
# L2.Frp                      -0.027248         0.120370           -0.226           0.821
# L2.SV                       -0.210021         0.143520           -1.463           0.143
# L2.SP                        0.046521         0.119904            0.388           0.698
# L2.KrF                      -0.028313         0.149173           -0.190           0.849
# L2.Venstre                  -0.100223         0.157426           -0.637           0.524
# L2.MDG                      -0.150878         0.154939           -0.974           0.330
# L2.Rodt                      0.071110         0.126520            0.562           0.574
# L2.Andre                     0.080911         0.132376            0.611           0.541
# L3.Ap                       -0.003121         0.114279           -0.027           0.978
# L3.Hoyre                    -0.043091         0.117531           -0.367           0.714
# L3.Frp                      -0.018510         0.115672           -0.160           0.873
# L3.SV                       -0.120222         0.137216           -0.876           0.381
# L3.SP                        0.104292         0.116283            0.897           0.370
# L3.KrF                       0.003018         0.139022            0.022           0.983
# L3.Venstre                  -0.056552         0.143962           -0.393           0.694
# L3.MDG                      -0.149048         0.145354           -1.025           0.305
# L3.Rodt                     -0.113018         0.122360           -0.924           0.356
# L3.Andre                     0.040808         0.125736            0.325           0.746
# =======================================================================================
#
# Correlation matrix of residuals
#                  Ap     Hoyre       Frp        SV        SP       KrF   Venstre       MDG      Rodt     Andre
# Ap         1.000000 -0.378746 -0.389825 -0.254323 -0.219754 -0.063368 -0.220318 -0.125914 -0.232777  0.022030
# Hoyre     -0.378746  1.000000 -0.220250 -0.122293 -0.220914 -0.168896  0.003002 -0.185372 -0.029083 -0.018643
# Frp       -0.389825 -0.220250  1.000000 -0.006612 -0.117173 -0.044680 -0.136671  0.011405 -0.092811 -0.198320
# SV        -0.254323 -0.122293 -0.006612  1.000000 -0.068324  0.086804  0.110788  0.069049  0.062271  0.054351
# SP        -0.219754 -0.220914 -0.117173 -0.068324  1.000000 -0.154968 -0.109352 -0.038753  0.140609 -0.231537
# KrF       -0.063368 -0.168896 -0.044680  0.086804 -0.154968  1.000000  0.248449  0.131669 -0.121385  0.016125
# Venstre   -0.220318  0.003002 -0.136671  0.110788 -0.109352  0.248449  1.000000  0.022259 -0.038285  0.059985
# MDG       -0.125914 -0.185372  0.011405  0.069049 -0.038753  0.131669  0.022259  1.000000 -0.067880  0.124482
# Rodt      -0.232777 -0.029083 -0.092811  0.062271  0.140609 -0.121385 -0.038285 -0.067880  1.000000  0.002041
# Andre      0.022030 -0.018643 -0.198320  0.054351 -0.231537  0.016125  0.059985  0.124482  0.002041  1.000000

# %%
# Compute R² for each party
r2_scores = {}
for party in ['Ap', 'Hoyre', 'Frp', 'SV', 'SP', 'KrF', 'Venstre', 'MDG', 'Rodt','Andre']:
    r2_scores[party] = r2_score(df_en[party].iloc[model_fitted.k_ar:], model_fitted.fittedvalues[party])

# Print R² values
for party, r2 in r2_scores.items():
    print(f"R² for {party}: {r2:.4f}")
# Out:
# R² for Ap: 0.2432
# R² for Hoyre: 0.3217
# R² for Frp: 0.2889
# R² for SV: 0.3326
# R² for SP: 0.2512
# R² for KrF: 0.4423
# R² for Venstre: 0.3234
# R² for MDG: 0.2778
# R² for Rodt: 0.3601
# R² for Andre: 0.3296

# %%
# Check if the VAR model is stable (roots inside the unit circle)
print("Is the VAR model stable?", model_fitted.is_stable())
# Out:
# Is the VAR model stable? True

# %%
all_fitted= model_fitted.fittedvalues

# %%
all_fitted
# Out:
#                   Ap     Hoyre       Frp        SV        SP       KrF  \
# Mnd
# 2008-10-31  0.175239  0.193507 -0.401586  0.551482 -0.175915  0.175727
# 2008-11-30  0.998017  0.033604 -0.444846 -0.048092 -0.575572  0.480170
# 2008-12-31  0.324334  0.931611 -0.084267 -0.140096 -0.085094 -0.515696
# 2009-01-31  2.448483 -1.677717 -0.945613 -0.160972  0.070238 -0.054654
# 2009-02-28  1.068307 -0.705292 -0.448062 -0.272113 -0.062370 -0.067812
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-31  1.674033 -0.653190 -0.643871 -0.264251 -0.714438  0.351266
# 2025-04-30 -0.637234  0.329283 -0.720838 -0.174213  0.486876  0.342840
# 2025-05-31  0.353616 -0.537558 -0.190647  0.677982 -0.288564  0.053469
# 2025-06-30  0.994482 -1.369838  0.569668 -0.521910  0.442132 -0.107433
# 2025-07-31  0.313891 -0.645757  0.609644  0.027445  0.016672 -0.196153
#
#              Venstre       MDG      Rodt     Andre
# Mnd
# 2008-10-31 -0.047160  0.007607 -0.270423 -0.200096
# 2008-11-30  0.075839 -0.207890 -0.318090 -0.060964
# 2008-12-31 -0.288531 -0.024757 -0.272653 -0.321489
# 2009-01-31  0.224616  0.006457 -0.036000 -0.123956
# 2009-02-28  0.489299  0.117308  0.058271 -0.103067
# ...              ...       ...       ...       ...
# 2025-03-31  0.321452 -0.017481 -0.214690  0.240778
# 2025-04-30  0.122418  0.269557  0.070006  0.050025
# 2025-05-31  0.055777 -0.237624  0.235397 -0.007610
# 2025-06-30 -0.153426  0.354917 -0.218967 -0.104575
# 2025-07-31 -0.095308  0.280035 -0.502389 -0.000663
#
# [202 rows x 10 columns]

# %%
steps = 2  # Number of steps to forecast
alpha = 0.50

forecast, lower, upper = model_fitted.forecast_interval(df_en.values[-model_fitted.k_ar:],  exog_future=ex_future, steps=steps, alpha=alpha)

# %%
forecast
# Out:
# array([[ 0.63054043,  0.8790016 , -1.33342866, -0.28884753,  0.02196346,
#          0.6059182 , -0.0053913 , -0.21901461, -0.45227429, -0.20761524],
#        [ 0.63614917,  0.01360233,  0.54226977, -0.38957744,  0.46902612,
#         -0.34535143, -0.0287338 , -0.12359155,  0.08366189, -0.70805953]])

# %%
forecast_dates = pd.date_range(start="2025-08-31", periods=steps, freq='ME')

last_actual_value = df_orig.iloc[-1]  # Last known actual data point

forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=df_en.columns)
forecast_lower_df=pd.DataFrame(lower, index=forecast_dates, columns=df_en.columns)
forecast_upper_df=pd.DataFrame(upper, index=forecast_dates, columns=df_en.columns)

forecast_df = forecast_df.cumsum() + last_actual_value
forecast_lower_df = forecast_lower_df.cumsum() + last_actual_value
forecast_upper_df = forecast_upper_df.cumsum() + last_actual_value

# %%
# Get forecast covariance in differenced scale
forecast_cov = model_fitted.forecast_cov(steps=steps)

# Cumulative sum of covariance matrices to restore original scale
for t in range(steps):
    forecast_cov[t] = np.sum(forecast_cov[:t+1], axis=0)

# Convert to DataFrames for readability
forecast_cov_df = {t: pd.DataFrame(forecast_cov[t], index=df_en.columns, columns=df_en.columns)
                            for t in range(steps)}

# %%
df_en=df_orig

# %%
# Define a color map for consistency
colors = {
    'Ap': '#FF0000',        # Red
    'Hoyre': '#0000FF',     # Blue
    'Frp': '#00008B',       # Dark Blue
    'SV': '#FF6347',        # Light Red (Tomato)
    'SP': '#006400',        # Dark Green
    'KrF': '#FFD700',       # Yellow (Gold)
    'Venstre': '#ADD8E6',   # Light Blue
    'MDG': '#008000',       # Green
    'Rodt': '#8B0000',      # Dark Red
    'Andre': '#808080'      # Gray
}

plt.figure(figsize=(12, 6))

for party in colors.keys():  # Iterate over defined parties
    color = colors[party]  

    # Plot actual data
    plt.plot(df_en.index, df_en[party], marker="o", color=color, label=f"{party}")

    # Plot forecast 
    plt.plot(forecast_df.index, forecast_df[party], linestyle="dashed", color=color)

    last_actual_date = df_en.index[-1]
    first_forecast_date = forecast_df.index[0]
    last_actual_value = df_en[party].iloc[-1]
    first_forecast_value = forecast_df[party].iloc[0]

    plt.plot([last_actual_date, first_forecast_date], [last_actual_value, first_forecast_value], color=color, linestyle="dashed")
    
    # Plot confidence interval (original scale)
    plt.fill_between(forecast_df.index, 
                     forecast_lower_df[party], 
                     forecast_upper_df[party], 
                     color=color, alpha=0.2)


dates = pd.date_range(start="2023-01-01", end="2025-09-30", freq="MS") 
for date in dates:
    plt.axvline(date, color="gray", linestyle="dotted", alpha=0.5)

# Add horizontal grid lines every 5%
for percent in range(0, 45, 1):
    plt.axhline(percent, color="gray", linestyle="dotted", alpha=0.5)

plt.xlim(np.datetime64("2025-01-01"), np.datetime64("2025-09-30"))  # Manually set max date to Sept 2025
plt.ylim(0,40)  # Manually set max date to Sept 2025
plt.xlabel("Tid")
plt.ylabel("Prosent oppslutning")
plt.title("OneSixtyNine v2.0: Partiers oppslutning med 50% konfidensintervall")
plt.legend(loc="upper left")
plt.show()

# %%
forecast_df=forecast_df[['Ap', 'Hoyre', 'Frp', 'SV', 'SP', 'KrF', 'Venstre', 'MDG', 'Rodt','Andre']]
forecast_lower_df=forecast_lower_df[['Ap', 'Hoyre', 'Frp', 'SV', 'SP', 'KrF', 'Venstre', 'MDG', 'Rodt','Andre']]
forecast_upper_df=forecast_upper_df[['Ap', 'Hoyre', 'Frp', 'SV', 'SP', 'KrF', 'Venstre', 'MDG', 'Rodt','Andre']]

# %%
###finn estimat for september
date_to_extract = "2025-09-30"

# Extract the row for the given date from each dataframe
estimate_row = forecast_df.loc[date_to_extract]
lower_row = forecast_lower_df.loc[date_to_extract]
upper_row = forecast_upper_df.loc[date_to_extract]

# Combine into a new DataFrame
result_df = pd.DataFrame({
    "Party": estimate_row.index,
    "Estimate": estimate_row.values,
    "Lower": lower_row.values,
    "Upper": upper_row.values
})

# Display the final structured DataFrame
print(result_df)
# Out:
#      Party   Estimate      Lower      Upper
# 0       Ap  28.766690  26.756911  30.776468
# 1    Hoyre  15.692604  14.050668  17.334540
# 2      Frp  20.708841  19.190244  22.227439
# 3       SV   7.521575   6.892900   8.150250
# 4       SP   6.790990   5.560366   8.021613
# 5      KrF   3.460567   2.966776   3.954357
# 6  Venstre   4.665875   4.084883   5.246867
# 7      MDG   3.157394   2.690293   3.624495
# 8     Rodt   5.531388   4.919960   6.142815
# 9    Andre   3.184325   2.657393   3.711257

# %%
# Multivariate MC!
n_sim = 1000000
# Extract mean estimates (yhat) and covariance matrix
yhat_vector = result_df["Estimate"].values  # Mean estimates for all parties
#yhat_vector = forecast_original_scale["Estimate"].values  # Mean estimates for all parties
cov_matrix = forecast_cov[-1]  # Covariance matrix at final step (latest forecast)

# Generate correlated samples
samples = np.random.multivariate_normal(yhat_vector, cov_matrix, size=n_sim)
samples = np.maximum(samples, 1e-6) ##must be above 0
samples = (samples.T / samples.sum(axis=1) * 100).T

# Create a DataFrame with sampled values
sampled_df = pd.DataFrame(samples, columns=result_df["Party"])

# Compute vote totals for each simulation
red_green_votes = sampled_df[["Ap", "SV", "SP", "Rodt", "MDG"]].sum(axis=1)/sampled_df.sum(axis=1)
blue_votes = sampled_df[["Hoyre", "Frp", "KrF", "Venstre"]].sum(axis=1)/sampled_df.sum(axis=1)

# Probability that red-green block wins
prob_red_green_wins = np.mean(red_green_votes > blue_votes)

print(f"Sannsyn for at Ap+SV+Sp+R+MDG > H+FrP+KrF+V: {prob_red_green_wins:.4f}")
# Out:
# Sannsyn for at Ap+SV+Sp+R+MDG > H+FrP+KrF+V: 0.9583

# %%
sampled_df.drop(columns=["Andre"], inplace=True)

# %%
sample_mandate=pd.DataFrame(columns=sampled_df.columns)

# %%
def calc_mandat(oppslutt):
    if oppslutt <4.0:
        mandat=np.round(1/4*oppslutt**2,0)
    else: 
        oppslutt=round(1.8119*oppslutt,0)
    return int(oppslutt)

# %%
for party in sampled_df.columns:
    sample_mandate[party]=sampled_df[party].apply(calc_mandat)

# %%
sample_mandate
# Out:
# Party   Ap  Hoyre  Frp  SV  SP  KrF  Venstre  MDG  Rodt
# 0       56     27   32  13  11    3        7    3    11
# 1       53     27   37  14  15    3        3    2    11
# 2       57     20   39  13  14    8        9    3    10
# 3       55     32   39  14   3    3        8    3    10
# 4       53     27   40  12  11    7       10    3     8
# ...     ..    ...  ...  ..  ..  ...      ...  ...   ...
# 999995  44     34   38  14  13    2        9    3    11
# 999996  55     22   44  13  13    3        9    2     8
# 999997  54     26   37  16  12    3        9    3    11
# 999998  51     33   38  14  14    3        3    2     9
# 999999  49     25   42  13  14    3        9    3    11
#
# [1000000 rows x 9 columns]

# %%
sample_mandate['Sum']=sample_mandate.sum(axis=1)

# %%
sample_mandate
# Out:
# Party   Ap  Hoyre  Frp  SV  SP  KrF  Venstre  MDG  Rodt  Sum
# 0       56     27   32  13  11    3        7    3    11  163
# 1       53     27   37  14  15    3        3    2    11  165
# 2       57     20   39  13  14    8        9    3    10  173
# 3       55     32   39  14   3    3        8    3    10  167
# 4       53     27   40  12  11    7       10    3     8  171
# ...     ..    ...  ...  ..  ..  ...      ...  ...   ...  ...
# 999995  44     34   38  14  13    2        9    3    11  168
# 999996  55     22   44  13  13    3        9    2     8  169
# 999997  54     26   37  16  12    3        9    3    11  171
# 999998  51     33   38  14  14    3        3    2     9  167
# 999999  49     25   42  13  14    3        9    3    11  169
#
# [1000000 rows x 10 columns]

# %%
sample_169=sample_mandate[sample_mandate["Sum"]==169].copy()

# %%
sample_169
# Out:
# Party   Ap  Hoyre  Frp  SV  SP  KrF  Venstre  MDG  Rodt  Sum
# 6       49     31   32  15  16    2        9    3    12  169
# 10      51     31   39  14   8    3       10    3    10  169
# 13      51     25   40  15  14    3        8    2    11  169
# 20      51     27   40  15  12    3        8    3    10  169
# 26      55     29   37  13  10    3        8    3    11  169
# ...     ..    ...  ...  ..  ..  ...      ...  ...   ...  ...
# 999976  54     25   40  15  12    3        7    3    10  169
# 999984  44     27   40  15  18    3        8    3    11  169
# 999992  48     29   41  12  13    3       10    3    10  169
# 999996  55     22   44  13  13    3        9    2     8  169
# 999999  49     25   42  13  14    3        9    3    11  169
#
# [193382 rows x 10 columns]

# %%
sample_169['red_green'] = sample_169[["Ap", "SV", "SP", "Rodt", "MDG"]].sum(axis=1)
sample_169['ap_sp'] = sample_169[["Ap", "SP"]].sum(axis=1)
sample_169['ap_sp_sv'] = sample_169[["Ap", "SP", "SV"]].sum(axis=1)
sample_169['ap_sp_sv_r'] = sample_169[["Ap", "SP", "SV", "Rodt"]].sum(axis=1)
sample_169['ap_sp_sv_r_mdg'] = sample_169[["Ap", "SP", "SV", "Rodt", "MDG"]].sum(axis=1)
sample_169['h_frp'] = sample_169[["Hoyre", "Frp"]].sum(axis=1)
sample_169['h_frp_v_krf'] = sample_169[["Hoyre", "Frp", "Venstre", "KrF"]].sum(axis=1)
sample_169['h_frp_v_krf_mdg'] = sample_169[["Hoyre", "Frp", "Venstre", "KrF", "MDG"]].sum(axis=1)

# %%
sample_169['red_green_victory'] = sample_169['red_green'] >= 85
sample_169['ap_sp_victory'] = sample_169['ap_sp'] >= 85
sample_169['ap_sp_sv_victory'] = sample_169['ap_sp_sv'] >= 85
sample_169['ap_sp_sv_r'] = sample_169['ap_sp_sv_r'] >= 85
sample_169['ap_sp_sv_r_mdg'] = sample_169['ap_sp_sv_r_mdg'] >= 85
sample_169['h_frp'] = sample_169['h_frp'] >= 85
sample_169['h_frp_v_krf'] = sample_169['h_frp_v_krf'] >= 85
sample_169['h_frp_v_krf_mdg'] = sample_169['h_frp_v_krf_mdg'] >= 85

# %%
print(sample_169['red_green_victory'].mean())
print(sample_169['ap_sp_victory'].mean())
print(sample_169['ap_sp_sv_victory'].mean())
print(sample_169['ap_sp_sv_r'].mean())
print(sample_169['ap_sp_sv_r_mdg'].mean())
print(sample_169['h_frp'].mean())
print(sample_169['h_frp_v_krf'].mean())
print(sample_169['h_frp_v_krf_mdg'].mean())
# Out:
# 0.9602910301889525
# 0.0
# 0.05438975706115357
# 0.8557828546607233
# 0.9602910301889525
# 0.0
# 0.039708969811047566
# 0.14421714533927665

# %%
import matplotlib.pyplot as plt

plt.hist(sample_169['ap_sp_sv'], bins=range(0, sample_169['ap_sp_sv'].max() + 2), edgecolor='black')
plt.title('Distribution of Mandates')
plt.xlabel('Mandates')
plt.ylabel('Number of Simulations')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
